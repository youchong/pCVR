# %%
import pandas as pd
import numpy as np
import random as rnd
import gc

# %%
train_data=pd.read_csv('Features/finaldata/train28drop.csv')

# %%
# train_data.drop(['haveBabyCounts','pocrCounts','telecomsOperatorCounts','genderCounts','hometownCounts','residenceCounts','marriageStatusCounts','appPlatformCounts'],axis=1,inplace=True)
train_data.drop(['residence','haveBaby','sicrCounts','poadCounts','ageCounts','appPlatform','education','sitesetIDCounts','userID','adID','telecomsOperator','creativeID','adIDCounts','siadCounts','educationCounts','marriageStatus'],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    label  connectionType  positionID  camgaignID  advertiserID  appID  \
# 0      0               2        6315        6290           453    382
# 1      0               1        4522        6026           445    149
# 2      0               0        4522        3774           457    359
# 3      0               0        4522        5725           435    368
# 4      0               2        7511        6679           316    374
#
#    appCategory  age  gender  hometown        ...          appCategoryconvrate  \
# 0          407    3       1      1503        ...                      0.01667
# 1          104    7       1      1506        ...                      0.02735
# 2          203    5       1      1209        ...                      0.03583
# 3          203    9       2         0        ...                      0.03583
# 4          201    2       2      1001        ...                      0.02552
#
#    cocrCounts  coadCounts  coapCounts  siapCounts  poapCounts  \
# ...

# %%
train_data.to_csv('Features/finaldata/train28drop.csv',index=False)

# %%
del train_data
gc.collect()
# Out:
# 467

# %%
valid_data=pd.read_csv('Features/finaldata/valid28drop.csv')

# %%
# valid_data.drop(['haveBabyCounts','pocrCounts','telecomsOperatorCounts','genderCounts','hometownCounts','residenceCounts','marriageStatusCounts','appPlatformCounts'],axis=1,inplace=True)
valid_data.drop(['residence','haveBaby','sicrCounts','poadCounts','ageCounts','appPlatform','education','sitesetIDCounts','userID','adID','telecomsOperator','creativeID','adIDCounts','siadCounts','educationCounts','marriageStatus'],axis=1,inplace=True)

# %%
valid_data.head()
# Out:
#    label  connectionType  positionID  camgaignID  advertiserID  appID  \
# 0      0               1        4522        3115             5    475
# 1      0               1       10410        5980           657     69
# 2      0               2         485        5265           561    395
# 3      0               0        6796        3642           311     12
# 4      0               1        6759        6646           554    403
#
#    appCategory  age  gender  hometown        ...          appCategoryconvrate  \
# 0          104    6       1      2404        ...                      0.02735
# 1          106    6       2         0        ...                      0.02454
# 2          503    3       1       511        ...                      0.02857
# 3          203    8       2         0        ...                      0.03583
# 4          201    5       0      1601        ...                      0.02552
#
#    cocrCounts  coadCounts  coapCounts  siapCounts  poapCounts  \
# ...

# %%
valid_data.to_csv('Features/finaldata/valid28drop.csv',index=False)

# %%
del valid_data
gc.collect()
# Out:
# 251

# %%
test_data=pd.read_csv('Features/finaldata/testdrop.csv')

# %%
# test_data.drop(['haveBabyCounts','pocrCounts','telecomsOperatorCounts','genderCounts','hometownCounts','residenceCounts','marriageStatusCounts','appPlatformCounts'],axis=1,inplace=True)
test_data.drop(['residence','haveBaby','sicrCounts','poadCounts','ageCounts','appPlatform','education','sitesetIDCounts','userID','adID','telecomsOperator','creativeID','adIDCounts','siadCounts','educationCounts','marriageStatus'],axis=1,inplace=True)

# %%
test_data.head()
# Out:
#    connectionType  positionID  camgaignID  advertiserID  appID  appCategory  \
# 0               1        4522        5921           311     12          203
# 1               1        1456        5342           316    374          201
# 2               1        4292        2360           565    375          203
# 3               1        3678        6686           649    441          503
# 4               1        4818        1155           215    365          301
#
#    age  gender  hometown  sitesetID        ...          appCategoryconvrate  \
# 0    5       2       208          2        ...                      0.03583
# 1    0       0         0          0        ...                      0.02552
# 2    7       1         0          0        ...                      0.03583
# 3    9       2       501          0        ...                      0.02857
# 4    1       1      2701          0        ...                      0.01605
#
# ...

# %%
test_data.to_csv('Features/finaldata/testdrop.csv',index=False)
