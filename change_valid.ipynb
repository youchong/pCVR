# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# %%
train_data=pd.read_csv('Features/finaldata/train_raw.csv')
# train_data=pd.read_csv('Features/finaldata/train28.csv')
# valid_data=pd.read_csv('Features/finaldata/valid_raw.csv')

# %%
train_data.shape
# Out:
# (14597343, 64)

# %%
train_data.head()
# Out:
#    label  clickTime  connectionType  conversionTime  creativeID  positionID  \
# 0      0     250000               2             NaN        8930        6315
# 1      0     250000               1             NaN       43695        4522
# 2      0     250000               0             NaN       28424        4522
# 3      0     250000               0             NaN       47347        4522
# 4      0     250000               2             NaN       16759        7511
#
#    telecomsOperator    userID   adID  camgaignID         ...           \
# 0                 1  18193893  20938        6290         ...
# 1                 1   4128332  16739        6026         ...
# 2                 0  17247261  20367        3774         ...
# 3                 0  14569685  12268        5725         ...
# 4                 1   8351850  15256        6679         ...
#
#    uspolast  creativeIDconvrate  positionIDconvrate  camgaignIDconvrate  \
# ...

# %%
temp=(train_data['clickTime']>=280000)&(train_data['clickTime']<290000)

# %%
train_data.drop(['clickTime','conversionTime'],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    label  connectionType  creativeID  positionID  telecomsOperator    userID  \
# 0      0               2        8930        6315                 1  18193893
# 1      0               1       43695        4522                 1   4128332
# 2      0               0       28424        4522                 0  17247261
# 3      0               0       47347        4522                 0  14569685
# 4      0               2       16759        7511                 1   8351850
#
#     adID  camgaignID  advertiserID  appID         ...           uspolast  \
# 0  20938        6290           453    382         ...              32052
# 1  16739        6026           445    149         ...                 -1
# 2  20367        3774           457    359         ...                 -1
# 3  12268        5725           435    368         ...                 -1
# 4  15256        6679           316    374         ...                 -1
#
# ...

# %%
train_data[temp].to_csv('Features/finaldata/valid28.csv',index=False)

# %%
train_data[~temp].to_csv('Features/finaldata/train28.csv',index=False)

# %%
train_data=pd.read_csv('Features/finaldata/train28.csv')
valid_data=pd.read_csv('Features/finaldata/valid_raw.csv')

# %%
train_data.head()
# Out:
#    label  connectionType  creativeID  positionID  telecomsOperator    userID  \
# 0      0               2        8930        6315                 1  18193893
# 1      0               1       43695        4522                 1   4128332
# 2      0               0       28424        4522                 0  17247261
# 3      0               0       47347        4522                 0  14569685
# 4      0               2       16759        7511                 1   8351850
#
#     adID  camgaignID  advertiserID  appID         ...           uspolast  \
# 0  20938        6290           453    382         ...              32052
# 1  16739        6026           445    149         ...                 -1
# 2  20367        3774           457    359         ...                 -1
# 3  12268        5725           435    368         ...                 -1
# 4  15256        6679           316    374         ...                 -1
#
# ...

# %%
valid_data.head()
# Out:
#    label  clickTime  connectionType  conversionTime  creativeID  positionID  \
# 0      0     300000               1             NaN       41047        3322
# 1      0     300000               1             NaN       39840         451
# 2      0     300000               1             NaN       16330        1248
# 3      0     300000               1             NaN       28424        4522
# 4      0     300000               1             NaN       23219        5909
#
#    telecomsOperator    userID   adID  camgaignID         ...           \
# 0                 2    980933  10483        1913         ...
# 1                 2  18935122  28685        3160         ...
# 2                 3  18744426  15790        6256         ...
# 3                 1  15857403  20367        3774         ...
# 4                 1   2343554  16346        2013         ...
#
#    uspolast  creativeIDconvrate  positionIDconvrate  camgaignIDconvrate  \
# ...

# %%
valid_data.drop(['clickTime','conversionTime'],axis=1,inplace=True)

# %%
train_data=pd.concat([train_data,valid_data])

# %%
train_data.head()
# Out:
#    label  connectionType  creativeID  positionID  telecomsOperator    userID  \
# 0      0               2        8930        6315                 1  18193893
# 1      0               1       43695        4522                 1   4128332
# 2      0               0       28424        4522                 0  17247261
# 3      0               0       47347        4522                 0  14569685
# 4      0               2       16759        7511                 1   8351850
#
#     adID  camgaignID  advertiserID  appID         ...           uspolast  \
# 0  20938        6290           453    382         ...              32052
# 1  16739        6026           445    149         ...                 -1
# 2  20367        3774           457    359         ...                 -1
# 3  12268        5725           435    368         ...                 -1
# 4  15256        6679           316    374         ...                 -1
#
# ...

# %%
train_data.tail()
# Out:
#          label  connectionType  creativeID  positionID  telecomsOperator  \
# 3364039      0               1        7151        1638                 1
# 3364040      0               1       14079        4252                 3
# 3364041      0               1        8200        5639                 3
# 3364042      0               1        3586        7149                 1
# 3364043      0               0       29543        2426                 3
#
#            userID   adID  camgaignID  advertiserID  appID  \
# 3364039   1079646  13750        4728            85    308
# 3364040  12368367  11247        5297           422    126
# 3364041  14873041  20869        1296           257    245
# 3364042     89477   2238         637             3    465
# 3364043  12482915   5975        3148           172    424
#
#                 ...           uspolast  creativeIDconvrate  \
# 3364039         ...                 -1             0.00466
# ...

# %%
train_data.to_csv('Features/finaldata/train28.csv',index=False)
