# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# %%
data1=pd.read_csv('Features/raw/data1.csv')
data2=pd.read_csv('Features/raw/data2.csv')

# %%
data1.head()
# Out:
#    clickTime  connectionType  conversionTime  creativeID  label  positionID  \
# 0     170000               1             NaN       31746      0        4522
# 1     170000               1             NaN       48795      0        4289
# 2     170000               1             NaN        6615      0        3255
# 3     170000               1             NaN       35911      0        7422
# 4     170000               1             NaN        9187      0        7219
#
#    telecomsOperator    userID   adID  camgaignID      ...       appCategory  \
# 0                 1   6762540  11261        2634      ...               104
# 1                 1    532848  18112        4938      ...               503
# 2                 1  19616027  15400        5397      ...               201
# 3                 1   8128760  21961        6208      ...                 0
# 4                 1   2748335  31059        5750      ...               201
#
# ...

# %%
data1.columns.values
# Out:
# array(['clickTime', 'connectionType', 'conversionTime', 'creativeID',
#        'label', 'positionID', 'telecomsOperator', 'userID', 'adID',
#        'camgaignID', 'advertiserID', 'appID', 'appPlatform', 'appCategory',
#        'age', 'gender', 'education', 'marriageStatus', 'haveBaby',
#        'hometown', 'residence', 'sitesetID', 'positionType'], dtype=object)

# %%
for value in ['connectionType', 'creativeID',
       'positionID', 'telecomsOperator', 'userID', 'adID',
       'camgaignID', 'advertiserID', 'appID', 'appPlatform', 'appCategory',
       'age', 'gender', 'education', 'marriageStatus', 'haveBaby',
       'hometown', 'residence', 'sitesetID', 'positionType']:
    data2[value+'Counts']=data2[value].map(data1[value].value_counts())
    data2[value+'Counts'].fillna(0,inplace=True)
    data2[value+'Counts']=data2[value+'Counts'].astype(int)
    data2.drop([value],axis=1,inplace=True)

# %%
data2.head()
# Out:
#    clickTime  conversionTime  label  connectionTypeCounts  creativeIDCounts  \
# 0     250000             NaN      0               2408425             26311
# 1     250000             NaN      0              16445135               436
# 2     250000             NaN      0                573291             38898
# 3     250000             NaN      0                573291             37946
# 4     250000             NaN      0               2408425              2496
#
#    positionIDCounts  telecomsOperatorCounts  userIDCounts  adIDCounts  \
# 0             37698                10315167             0       35231
# 1            624059                10315167             0         436
# 2            624059                  686571             0       38898
# 3            624059                  686571             0       37946
# 4             34434                10315167             0        2963
#
#    camgaignIDCounts         ...          appCategoryCounts  ageCounts  \
# ...

# %%
data2.shape
# Out:
# (21283135, 23)

# %%
data2.drop(['clickTime','conversionTime','label'],axis=1,inplace=True)

# %%
data2.shape
# Out:
# (21283135, 20)

# %%
data2.to_csv('Features/counts/data2_counts.csv',index=False)
